// %%
完善实体类：在model包中创建对应的Java类

实现数据访问层：在dao包中创建数据库操作类

编写业务逻辑：在service包中实现业务逻辑

创建用户界面：完善CLIInterface.java

添加测试：在test目录下编写单元测试


AnimalService – 动物管理
EnclosureService – 展区管理
EmployeeService – 员工管理
FeedService – 饲料库存管理
FeedingService – 投喂流程管理
UserService – 用户账号、登录相关业务
AuthService – 授权与权限检查（基于 user/permission/role_permission）
PermissionService – 权限与角色-权限关系维护
LogService – 登录/操作日志记录与查询
SystemConfigService – 系统配置
